# %%
pip install pandas

# %%
d=[1,2,3,4,5]
d=pd.Series(d)
d

# %%
d={
    "name":["arsalan","faheem","sibtain"],
     "age":[24,24,24],
     "city":["pulwama","srinagar","srinagar"]
    }

# %%
print(d)

# %%
d2 = pd.DataFrame(d)
d2

# %%
import pandas as pd

# %%
df=pd.read_csv(r"H:\datasets\archive\train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.iloc[0,3]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
df.loc[714,"Name"]
# Out:
# 'Greenberg, Mr. Samuel'

# %%
# Out:
# <bound method DataFrame.sum of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.loc[:,"Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df.loc[0,"Name"]="arsalan"

# %%
df.iloc[0,3]="ayan"

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                               ayan    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.sort_values(by="Fare",ascending=True)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 271          272         1       3        Tornquist, Mr. William Henry
# 597          598         0       3                 Johnson, Mr. Alfred
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 277          278         0       2         Parkes, Mr. Francis "Frank"
# ..           ...       ...     ...                                 ...
# 438          439         0       1                   Fortune, Mr. Mark
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 737          738         1       1              Lesurer, Mr. Gustave J
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
df.sort_values(by="Fare",ascending=False,inplace=True)

# %%
df.head()
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 88   female  23.0      3      2     19950  263.0000  C23 C25 C27        S
# 27     male  19.0      3      2     19950  263.0000  C23 C25 C27        S

# %%
df["Age"].max()
# Out:
# 80.0

# %%
df["Age"].min()
# Out:
# 0.42

# %%
df["Fare"].mean()
# Out:
# np.float64(32.204207968574636)

# %%
df.sort_values(by="Fare",ascending=False,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
# ..           ...       ...     ...                                 ...
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 732          733         0       2                Knight, Mr. Robert J
# 674          675         0       2          Watson, Mr. Ennis Hastings
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
df["Fare"].sum()
# Out:
# np.float64(28693.9493)

# %%
df["Age"].isnull().sum()
# Out:
# np.int64(177)

# %%
df["Age"].notnull().sum()
# Out:
# np.int64(714)

# %%
df["Name"].count()
# Out:
# np.int64(891)

# %%
alive=df[(df["Age"]>18) &
        (df["Sex"]=="female")&
        (df["Survived"]==1)
        ]

# %%
alive
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 874          875         1       2
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d1=df[['Age','Name','Sex']]

# %%
d1.head()
# Out:
#     Age                                               Name     Sex
# 0  22.0                            Braund, Mr. Owen Harris    male
# 1  38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2  26.0                             Heikkinen, Miss. Laina  female
# 3  35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4  35.0                           Allen, Mr. William Henry    male

# %%
df[df['Age']>18]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
alive.shape
# Out:
# (151, 12)

# %%
df[df['Name'].str.contains("Rose")]
# Out:
#      PassengerId  Survived  Pclass                        Name     Sex   Age  \
# 855          856         1       3  Aks, Mrs. Sam (Leah Rosen)  female  18.0
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 855      0      1  392091  9.35   NaN        S

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df["Age"].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df[df['Name'].isin(['Braund, Mr. Owen Harris'])]
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
df.replace('Braund, Mr. Owen Harris','arsalan',inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                                              arsalan    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["Arsalan", "Rahul", "Ayesha", "Zaid", "Sara"],
    "Age": [24, 17, 22, 30, 19],
    "City": ["Pulwama", "Delhi", "Srinagar", "Delhi", "Mumbai"],
    "Marks": [85, 72, 91, 65, 88]
})

# %% [markdown]
# Level 1 — Basic
#
# 1. Print the DataFrame.
#
# 2. Display the first 3 rows.
#
# 3. Display the last 2 rows.
#
# 4. Find the shape of the DataFrame.
#
# 5. Display all column names.
#
# 6. Display the data types.

# %%
df
# Out:
#       Name  Age      City  Marks
# 0  Arsalan   24   Pulwama     85
# 1    Rahul   17     Delhi     72
# 2   Ayesha   22  Srinagar     91
# 3     Zaid   30     Delhi     65
# 4     Sara   19    Mumbai     88

# %%
df.head(3)
# Out:
#       Name  Age      City  Marks
# 0  Arsalan   24   Pulwama     85
# 1    Rahul   17     Delhi     72
# 2   Ayesha   22  Srinagar     91

# %%
df.tail(2)
# Out:
#    Name  Age    City  Marks
# 3  Zaid   30   Delhi     65
# 4  Sara   19  Mumbai     88

# %%
df.shape
# Out:
# (5, 4)

# %%
df.shape[0]
# Out:
# 5

# %%
df.shape[1]
# Out:
# 4

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City', 'Marks'], dtype='object')

# %%
df.dtypes
# Out:
# Name     object
# Age       int64
# City     object
# Marks     int64
# dtype: object

# %% [markdown]
# Level 2 — Selecting
#
# 7. Display only the Name column.
#
# 8. Display Name and Marks.
#
# 9. Using iloc, display the first row.
#
# 10. Using loc, display the City of row 2.

# %%
df.loc[:,"Name"]
# Out:
# 0    Arsalan
# 1      Rahul
# 2     Ayesha
# 3       Zaid
# 4       Sara
# Name: Name, dtype: object

# %%
df.iloc[0]
# Out:
# Name     Arsalan
# Age           24
# City     Pulwama
# Marks         85
# Name: 0, dtype: object

# %%
df.loc[1,"City"]
# Out:
# 'Delhi'

# %% [markdown]
# import pandas as pd
#
# df = pd.DataFrame({
#     "Name": ["Arsalan", "Rahul", "Ayesha", "Zaid", "Sara"],
#     "Age": [24, 17, 22, 30, 19],
#     "City": ["Pulwama", "Delhi", "Srinagar", "Delhi", "Mumbai"],
#     "Marks": [85, 72, 91, 65, 88]
# })

# %% [markdown]
# Find the highest Marks.
#
# 12. Find the lowest Marks.
#
# 13. Find the average Marks.
#
# 14. Find the total Marks.
#
# 15. Count the number of Names.

# %%
df["Marks"].min()
# Out:
# 65

# %%
df["Marks"].mean()
# Out:
# np.float64(80.2)

# %%
df["Marks"].sum()
# Out:
# np.int64(401)

# %%
df["Name"].value_counts().sum()
# Out:
# np.int64(5)

# %% [markdown]
# Level 4 — Filtering
#
# 16. Display students whose Marks are greater than 80.
#
# 17. Display students whose Age is greater than 20.
#
# 18. Display students from Delhi.
#
# 19. Display students whose Marks are greater than 80 AND Age is greater than 20.

# %%
df[df["Marks"]>80]
# Out:
#       Name  Age      City  Marks
# 0  Arsalan   24   Pulwama     85
# 2   Ayesha   22  Srinagar     91
# 4     Sara   19    Mumbai     88

# %%
df[df["Age"]>20]
# Out:
#       Name  Age      City  Marks
# 0  Arsalan   24   Pulwama     85
# 2   Ayesha   22  Srinagar     91
# 3     Zaid   30     Delhi     65

# %%
df[df["City"]=="Delhi"]
# Out:
#     Name  Age   City  Marks
# 1  Rahul   17  Delhi     72
# 3   Zaid   30  Delhi     65

# %%
filtera=df[
    (df["Marks"]>80 )&
    (df["Age"]>20)
]

# %%
filtera
# Out:
#       Name  Age      City  Marks
# 0  Arsalan   24   Pulwama     85
# 2   Ayesha   22  Srinagar     91

# %% [markdown]
# Level 5 — Pandas skills
#
# 20. Sort the DataFrame by Marks from lowest to highest.
#
# 21. Sort it from highest to lowest.
#
# 22. Count how many students are from each city.
#
# 23. Find students whose City is either Delhi or Mumbai using isin().
#
# 24. Change "Arsalan" to "arsalan" using loc.
#
# 25. Use str.contains() to find names containing "a".

# %%
df.sort_values(by="Marks",ascending=True,inplace=True)

# %%
df
# Out:
#       Name  Age      City  Marks
# 3     Zaid   30     Delhi     65
# 1    Rahul   17     Delhi     72
# 0  Arsalan   24   Pulwama     85
# 4     Sara   19    Mumbai     88
# 2   Ayesha   22  Srinagar     91

# %%
df.sort_values(by="Marks",ascending=False,inplace=True)

# %%
df
# Out:
#       Name  Age      City  Marks
# 2   Ayesha   22  Srinagar     91
# 4     Sara   19    Mumbai     88
# 0  Arsalan   24   Pulwama     85
# 1    Rahul   17     Delhi     72
# 3     Zaid   30     Delhi     65

# %%
df["City"].value_counts()
# Out:
# City
# Delhi       2
# Srinagar    1
# Mumbai      1
# Pulwama     1
# Name: count, dtype: int64

# %%
df[df["City"].isin(["Mumbai","Delhi"])]
# df[df['Name'].isin(['Braund, Mr. Owen Harris'])]
# Out:
#     Name  Age    City  Marks
# 4   Sara   19  Mumbai     88
# 1  Rahul   17   Delhi     72
# 3   Zaid   30   Delhi     65

# %%
df
# Out:
#       Name  Age      City  Marks
# 2   Ayesha   22  Srinagar     91
# 4     Sara   19    Mumbai     88
# 0  Arsalan   24   Pulwama     85
# 1    Rahul   17     Delhi     72
# 3     Zaid   30     Delhi     65

# %%
df.loc[df["Name"]=="Arsalan","Name"]="arsalan"

# %%
df
# Out:
#       Name  Age      City  Marks
# 2   Ayesha   22  Srinagar     91
# 4     Sara   19    Mumbai     88
# 0  arsalan   24   Pulwama     85
# 1    Rahul   17     Delhi     72
# 3     Zaid   30     Delhi     65

# %%
df.loc[df["Name"].str.contains("a",case=False,na=False),"Name"]
# Out:
# 2     Ayesha
# 4       Sara
# 0    arsalan
# 1      Rahul
# 3       Zaid
# Name: Name, dtype: object

# %%
df.rename(columns={"Pclass":"Pc"},inplace=True)

# %%
df.head(2)
# Out:
#              Survived  Pc                                               Name  \
# PassengerId
# 1                   0   3                            Braund, Mr. Owen Harris
# 2                   1   1  Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#                 Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1              male  22.0      1      0  A/5 21171   7.2500   NaN        S
# 2            female  38.0      1      0   PC 17599  71.2833   C85        C

# %%
df.set_index("PassengerId",inplace=True)

# %%
df["Age"].nunique()
# Out:
# 89

# %%
df.dropna()
# Out:
#              Survived  Pc                                               Name  \
# PassengerId
# 2                   1   1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 4                   1   1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 7                   0   1                            McCarthy, Mr. Timothy J
# 11                  1   3                    Sandstrom, Miss. Marguerite Rut
# 12                  1   1                           Bonnell, Miss. Elizabeth
# ...               ...  ..                                                ...
# 872                 1   1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 873                 0   1                           Carlsson, Mr. Frans Olof
# 880                 1   1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 888                 1   1                       Graham, Miss. Margaret Edith
# 890                 1   1                              Behr, Mr. Karl Howell
#
# ...

# %%
df.fillna("Unknown")
# Out:
#              Survived  Pc                                               Name  \
# PassengerId
# 1                   0   3                            Braund, Mr. Owen Harris
# 2                   1   1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                   1   3                             Heikkinen, Miss. Laina
# 4                   1   1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0   3                           Allen, Mr. William Henry
# ...               ...  ..                                                ...
# 887                 0   2                              Montvila, Rev. Juozas
# 888                 1   1                       Graham, Miss. Margaret Edith
# 889                 0   3           Johnston, Miss. Catherine Helen "Carrie"
# 890                 1   1                              Behr, Mr. Karl Howell
# 891                 0   3                                Dooley, Mr. Patrick
#
# ...

# %%
df.rename(columns={"Sex":"Gender"},inplace=True)

# %%
df["Age"]=df["Age"].fillna(df["Age"].mean())

# %%
df
# Out:
#              Survived  Pc                                               Name  \
# PassengerId
# 1                 NaN   3                            Braund, Mr. Owen Harris
# 2                 NaN   1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                 NaN   3                             Heikkinen, Miss. Laina
# 4                 NaN   1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                 NaN   3                           Allen, Mr. William Henry
# ...               ...  ..                                                ...
# 887               NaN   2                              Montvila, Rev. Juozas
# 888               NaN   1                       Graham, Miss. Margaret Edith
# 889               NaN   3           Johnston, Miss. Catherine Helen "Carrie"
# 890               NaN   1                              Behr, Mr. Karl Howell
# 891               NaN   3                                Dooley, Mr. Patrick
#
# ...

# %%
df["Embarked"]=df["Embarked"].fillna("unknown")

# %%
df.dropna(subset=["Age"],inplace=True)

# %%
df["Survived"]=df["Survived"].map({0:"Dead",1:"Alive"})

# %%
df.head(2)
# Out:
#    PassengerId Survived  Pclass  \
# 0            1     Dead       3
# 1            2    Alive       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.head(2)
# Out:
#    PassengerId Survived  Pclass  \
# 0            1     Dead       3
# 1            2    Alive       1
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  NaN  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  NaN  38.0      1      0
#
#       Ticket     Fare Cabin Embarked
# 0  A/5 21171   7.2500   NaN        S
# 1   PC 17599  71.2833   C85        C

# %%
df["Sex"]=df["Sex"].map({"male":1,"female":0})

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
#
#       Ticket     Fare Cabin Embarked
# 0  A/5 21171   7.2500   NaN        S
# 1   PC 17599  71.2833   C85        C

# %% [markdown]
# 1. Display the first 5 rows.
# 2. Display the first 10 rows.
# 3. Display the last 5 rows.
# 4. Find the number of rows and columns.
# 5. Display all column names.
# 6. Display the data type of every column.
# 7. Get complete basic information about the DataFrame.
# 8. Find how many rows are present.
# 9. Find how many columns are present.

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape[0]
# Out:
# 891

# %%
df.shape[1]
# Out:
# 12

# %% [markdown]
# 0. Display only the Name column.
# 11. Display only the Age column.
# 12. Display only the Fare column.
# 13. Display Name and Age.
# 14. Display Name, Sex, and Age.
# 15. Display PassengerId, Name, and Fare.
# 16. Display Survived, Sex, and Pclass.

# %%
df["Name"]
df["Age"]
df["Fare"]
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
df[['Name','Age','Sex']]
# Out:
#                                                   Name   Age     Sex
# 0                              Braund, Mr. Owen Harris  22.0    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                               Heikkinen, Miss. Laina  26.0  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                             Allen, Mr. William Henry  35.0    male
# ..                                                 ...   ...     ...
# 886                              Montvila, Rev. Juozas  27.0    male
# 887                       Graham, Miss. Margaret Edith  19.0  female
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN  female
# 889                              Behr, Mr. Karl Howell  26.0    male
# 890                                Dooley, Mr. Patrick  32.0    male
#
# [891 rows x 3 columns]

# %%
df[['Survived','Sex','Pclass']]
# Out:
#      Survived     Sex  Pclass
# 0           0    male       3
# 1           1  female       1
# 2           1  female       3
# 3           1  female       1
# 4           0    male       3
# ..        ...     ...     ...
# 886         0    male       2
# 887         1  female       1
# 888         0  female       3
# 889         1    male       1
# 890         0    male       3
#
# [891 rows x 3 columns]

# %% [markdown]
# 17. Using iloc, display the first row.
# 18. Using iloc, display the second row.
# 19. Display the first 5 rows using iloc.
# 20. Display rows 10 through 20 using iloc.
# 21. Using iloc, select the value in the first row and first column.
# 22. Using iloc, select the first 5 rows and first 3 columns.
# 23. Using iloc, select rows 0–9 and columns 0–4.

# %%
df.iloc[:6]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df.iloc[10:21]
# Out:
#     PassengerId  Survived  Pclass  \
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ...

# %%
df.iloc[0,0]
# Out:
# np.int64(1)

# %%
df.iloc[:6,:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry
# 5                                   Moran, Mr. James

# %%
df.iloc[0:9,0:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
#
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry
# 5                                   Moran, Mr. James
# 6                            McCarthy, Mr. Timothy J
# 7                     Palsson, Master. Gosta Leonard
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)

# %% [markdown]
# 24. Using loc, get the Name of row 0.
# 25. Using loc, get the Age of row 10.
# 26. Using loc, get the Fare of row 50.
# 27. Using loc, display the Name and Age of row 100.
# 28. Using loc, display the Name column for rows 0–10.

# %%
df.loc[0,"Name"]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
df.loc[10,"Age"]
# Out:
# np.float64(4.0)

# %%
df.loc[50,"Fare"]
# Out:
# np.float64(39.6875)

# %%
df.loc[100,["Name","Age"]]
# Out:
# Name    Petranec, Miss. Matilda
# Age                        28.0
# Name: 100, dtype: object

# %%
df.loc[:11,'Name']
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# Name: Name, dtype: object

# %% [markdown]
# 29. Find the maximum age.
# 30. Find the minimum age.
# 31. Find the average age.
# 32. Find the maximum fare.
# 33. Find the minimum fare.
# 34. Find the average fare.
# 35. Find the total fare paid.
# 36. Count the non-missing values in Age.
# 37. Count the non-missing values in Cabin.
# 38. Find the average number of siblings/spouses (SibSp).
# 39. Find the average number of parents/children (Parch).

# %%
df["Age"].max()
# Out:
# 80.0

# %%
df["Age"].min()
# Out:
# 0.42

# %%
df["Age"].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df["Fare"].max()
# Out:
# 512.3292

# %%
df["Fare"].min()
# Out:
# 0.0

# %%
df["Fare"].sum()
# Out:
# np.float64(28693.9493)

# %%
df["Age"].count()
# Out:
# np.int64(714)

# %%
df["Cabin"].count()
# Out:
# np.int64(204)

# %%
df['SibSp'].mean()
# Out:
# np.float64(0.5230078563411896)

# %%
df['Parch'].mean()
# Out:
# np.float64(0.38159371492704824)

# %% [markdown]
# 0. Check which values in Age are missing.
# 41. Count how many Age values are missing.
# 42. Count how many Cabin values are missing.
# 43. Count how many Embarked values are missing.
# 44. Find the number of non-missing Age values.
# 45. Find the number of non-missing Cabin values.
# 46. Find which columns contain missing values.
# 47. Find the total number of missing values in the entire DataFrame.

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(177)

# %%
df['Cabin'].isnull().sum()
# Out:
# np.int64(687)

# %%
df["Embarked"].isnull().sum()
# Out:
# np.int64(2)

# %%
df['Age'].notnull().sum()
# Out:
# np.int64(714)

# %%
df['Cabin'].notnull().sum()
# Out:
# np.int64(204)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(866)

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %% [markdown]
# Display passengers older than 30.
# 49. Display passengers younger than 18.
# 50. Display passengers whose age is exactly 25.
# 51. Display all female passengers.
# 52. Display all male passengers.
# 53. Display passengers who survived.
# 54. Display passengers who did not survive.
# 55. Display passengers travelling in first class.
# 56. Display passengers travelling in third class.
# 57. Display passengers whose fare is greater than 50.
# 58. Display passengers whose fare is less than 10.

# %%
df[df['Age']>30]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Age']<18]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 853          854         1       1                Lines, Miss. Mary Conover
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
df[df['Age']==25]
# Out:
#      PassengerId  Survived  Pclass  \
# 75            76         0       3
# 134          135         0       2
# 246          247         0       3
# 267          268         1       3
# 271          272         1       3
# 343          344         0       2
# 353          354         0       3
# 370          371         1       1
# 442          443         0       3
# 484          485         1       1
# 498          499         0       1
# 580          581         1       2
# 666          667         0       2
# 685          686         0       2
# 693          694         0       3
# 703          704         0       3
# 728          729         0       2
# 729          730         0       3
# 784          785         0       3
# 785          786         0       3
# 794          795         0       3
# 880          881         1       2
# 884          885         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# ...

# %%
df[df['Sex']=='female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Survived']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Survived']==0]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df[df['Pclass']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Pclass']==3]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df[df['Fare']>50]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 27            28         0       1
# 31            32         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Fare']<10]
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris    male
# 2              3         1       3          Heikkinen, Miss. Laina  female
# 4              5         0       3        Allen, Mr. William Henry    male
# 5              6         0       3                Moran, Mr. James    male
# 12            13         0       3  Saundercock, Mr. William Henry    male
# ..           ...       ...     ...                             ...     ...
# 877          878         0       3            Petroff, Mr. Nedelio    male
# 878          879         0       3              Laleff, Mr. Kristo    male
# 881          882         0       3              Markun, Mr. Johann    male
# 884          885         0       3          Sutehall, Mr. Henry Jr    male
# 890          891         0       3             Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket    Fare Cabin Embarked
# ...

# %% [markdown]
# 59. Find female passengers older than 30.
# 60. Find male passengers younger than 20.
# 61. Find passengers older than 50 who survived.
# 62. Find passengers younger than 18 who survived.
# 63. Find female passengers who survived.
# 64. Find female passengers who did not survive.
# 65. Find passengers in first class who survived.
# 66. Find passengers in third class who did not survive.
# 67. Find passengers older than 40 AND travelling in first class.
# 68. Find passengers whose fare is greater than 100 AND who survived.
# 69. Find passengers who are female OR survived.

# %%
df[(df['Age']>30)&
   (df['Sex']=='female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 15            16         1       2
# 18            19         0       3
# ..           ...       ...     ...
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Age']<20)&
   (df['Sex']=='male')]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 16            17         0       3                     Rice, Master. Eugene
# 27            28         0       1           Fortune, Mr. Charles Alexander
# 50            51         0       3               Panula, Master. Juha Niilo
# 59            60         0       3       Goodwin, Master. William Frederick
# ..           ...       ...     ...                                      ...
# 841          842         0       2                 Mudd, Mr. Thomas Charles
# 844          845         0       3                      Culumovic, Mr. Jeso
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 869          870         1       3          Johnson, Master. Harold Theodor
# 877          878         0       3                     Petroff, Mr. Nedelio
#
# ...

# %%
df[(df['Age']>50)&
   (df['Survived']==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 11            12         1       1
# 15            16         1       2
# 195          196         1       1
# 268          269         1       1
# 275          276         1       1
# 366          367         1       1
# 449          450         1       1
# 483          484         1       3
# 496          497         1       1
# 513          514         1       1
# 570          571         1       2
# 571          572         1       1
# 587          588         1       1
# 591          592         1       1
# 630          631         1       1
# 647          648         1       1
# 765          766         1       1
# 774          775         1       2
# 820          821         1       1
# 829          830         1       1
# 857          858         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# ...

# %%
df[(df['Age']<18)&
   (df['Survived']==1)]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 9             10         1       2       Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 22            23         1       3               McGowan, Miss. Anna "Annie"
# 39            40         1       3               Nicola-Yarred, Miss. Jamila
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# ..           ...       ...     ...                                       ...
# 830          831         1       3   Yasbeck, Mrs. Antoni (Selini Alexander)
# 831          832         1       2           Richards, Master. George Sibley
# 853          854         1       1                 Lines, Miss. Mary Conover
# 869          870         1       3           Johnson, Master. Harold Theodor
# 875          876         1       3          Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
df[(df['Sex']=="female")&
   (df['Survived']==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Sex']=="female")&
   (df['Survived']==0)]
# Out:
#      PassengerId  Survived  Pclass  \
# 14            15         0       3
# 18            19         0       3
# 24            25         0       3
# 38            39         0       3
# 40            41         0       3
# ..           ...       ...     ...
# 854          855         0       2
# 863          864         0       3
# 882          883         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 38                  Vander Planke, Miss. Augusta Maria  female  18.0      2
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Pclass']==1)&
   (df['Survived']==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 23            24         1       1
# 31            32         1       1
# ..           ...       ...     ...
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Pclass']==3)&
   (df['Survived']==0)]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 12            13         0       3            Saundercock, Mr. William Henry
# ..           ...       ...     ...                                       ...
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df[(df['Pclass']==1)&
   (df['Age']>40)]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 35            36         0       1
# 52            53         1       1
# 54            55         0       1
# ..           ...       ...     ...
# 856          857         1       1
# 857          858         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 35                      Holverson, Mr. Alexander Oskar    male  42.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 54                      Ostby, Mr. Engelhart Cornelius    male  65.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Fare']>100)&
   (df['Survived']==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 31            32         1       1
# 88            89         1       1
# 195          196         1       1
# 215          216         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 299          300         1       1
# 305          306         1       1
# 306          307         1       1
# 307          308         1       1
# 311          312         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 334          335         1       1
# 337          338         1       1
# 341          342         1       1
# 380          381         1       1
# 390          391         1       1
# 393          394         1       1
# 435          436         1       1
# 537          538         1       1
# 550          551         1       1
# 581          582         1       1
# ...

# %%
df[(df['Sex']=='female')|
   (df['Survived']==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 70. Show the Name and Age of passengers older than 40.
# 71. Show Name, Sex, and Age of female passengers.
# 72. Show Name, Fare, and Pclass of first-class passengers.
# 73. Show Name, Age, and Survived of passengers younger than 18.
# 74. Show Name, Sex, and Fare of passengers who paid more than 100.

# %%
df[df['Age']>40][['Name','Age']]
# Out:
#                                                   Name   Age
# 6                              McCarthy, Mr. Timothy J  54.0
# 11                            Bonnell, Miss. Elizabeth  58.0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   55.0
# 33                               Wheadon, Mr. Edward H  66.0
# 35                      Holverson, Mr. Alexander Oskar  42.0
# ..                                                 ...   ...
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  48.0
# 865                           Bystrom, Mrs. (Karolina)  42.0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  47.0
# 873                        Vander Cruyssen, Mr. Victor  47.0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0
#
# [150 rows x 2 columns]

# %%
df[df['Sex']=='female'][['Name','Age','Sex']]
# Out:
#                                                   Name   Age     Sex
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                               Heikkinen, Miss. Laina  26.0  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  female
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  14.0  female
# ..                                                 ...   ...     ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  25.0  female
# 882                       Dahlberg, Miss. Gerda Ulrika  22.0  female
# 885               Rice, Mrs. William (Margaret Norton)  39.0  female
# 887                       Graham, Miss. Margaret Edith  19.0  female
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN  female
#
# [314 rows x 3 columns]

# %%
df[df['Pclass']==1][['Name','Fare','Pclass']]
# Out:
#                                                   Name     Fare  Pclass
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833       1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000       1
# 6                              McCarthy, Mr. Timothy J  51.8625       1
# 11                            Bonnell, Miss. Elizabeth  26.5500       1
# 23                        Sloper, Mr. William Thompson  35.5000       1
# ..                                                 ...      ...     ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  52.5542       1
# 872                           Carlsson, Mr. Frans Olof   5.0000       1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  83.1583       1
# 887                       Graham, Miss. Margaret Edith  30.0000       1
# 889                              Behr, Mr. Karl Howell  30.0000       1
#
# [216 rows x 3 columns]

# %%
df[(df['Age']<18)&
       (df['Survived']==1)][['Name','Age','Survived']]
# Out:
#                                          Name    Age  Survived
# 9         Nasser, Mrs. Nicholas (Adele Achem)  14.00         1
# 10            Sandstrom, Miss. Marguerite Rut   4.00         1
# 22                McGowan, Miss. Anna "Annie"  15.00         1
# 39                Nicola-Yarred, Miss. Jamila  14.00         1
# 43   Laroche, Miss. Simonne Marie Anne Andree   3.00         1
# ..                                        ...    ...       ...
# 830   Yasbeck, Mrs. Antoni (Selini Alexander)  15.00         1
# 831           Richards, Master. George Sibley   0.83         1
# 853                 Lines, Miss. Mary Conover  16.00         1
# 869           Johnson, Master. Harold Theodor   4.00         1
# 875          Najib, Miss. Adele Kiamie "Jane"  15.00         1
#
# [61 rows x 3 columns]

# %%
df[df['Fare']>100][['Name','Sex','Fare']]
# Out:
#                                                   Name     Sex      Fare
# 27                      Fortune, Mr. Charles Alexander    male  263.0000
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female  146.5208
# 88                          Fortune, Miss. Mabel Helen  female  263.0000
# 118                           Baxter, Mr. Quigg Edmond    male  247.5208
# 195                               Lurette, Miss. Elise  female  146.5208
# 215                            Newell, Miss. Madeleine  female  113.2750
# 258                                   Ward, Miss. Anna  female  512.3292
# 268      Graham, Mrs. William Thompson (Edith Junkins)  female  153.4625
# 269                             Bissette, Miss. Amelia  female  135.6333
# 297                       Allison, Miss. Helen Loraine  female  151.5500
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  247.5208
# 305                     Allison, Master. Hudson Trevor    male  151.5500
# ...

# %% [markdown]
# Count how many males and females there are.
# 76. Count how many passengers survived and didn't survive.
# 77. Count passengers in each passenger class.
# 78. Count passengers from each embarkation location.
# 79. Count the different values in SibSp.
# 80. Count the different values in Parch.
# 81. Count the different ages using value_counts().

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %% [markdown]
# Sort passengers by age from youngest to oldest.
# 83. Sort passengers by age from oldest to youngest.
# 84. Sort passengers by fare from lowest to highest.
# 85. Sort passengers by fare from highest to lowest.
# 86. Sort passengers by Pclass.
# 87. Sort passengers by Survived.
# 88. Sort passengers by Name alphabetically.

# %%
df.sort_values(by="Age",ascending=True)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.sort_values(by="Age",ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.sort_values(by="Fare",ascending=True)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 271          272         1       3        Tornquist, Mr. William Henry
# 597          598         0       3                 Johnson, Mr. Alfred
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 277          278         0       2         Parkes, Mr. Francis "Frank"
# ..           ...       ...     ...                                 ...
# 438          439         0       1                   Fortune, Mr. Mark
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 737          738         1       1              Lesurer, Mr. Gustave J
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
df.sort_values(by="Fare",ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
# ..           ...       ...     ...                                 ...
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 732          733         0       2                Knight, Mr. Robert J
# 674          675         0       2          Watson, Mr. Ennis Hastings
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
df.sort_values(by='Pclass')
# Out:
#      PassengerId  Survived  Pclass  \
# 445          446         1       1
# 310          311         1       1
# 309          310         1       1
# 307          308         1       1
# 306          307         1       1
# ..           ...       ...     ...
# 379          380         0       3
# 381          382         1       3
# 382          383         0       3
# 371          372         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 445                          Dodge, Master. Washington    male   4.0      0
# 310                     Hays, Miss. Margaret Bechstein  female  24.0      0
# 309                     Francatelli, Miss. Laura Mabel  female  30.0      0
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...  female  17.0      1
# 306                            Fleming, Miss. Margaret  female   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sort_values(by="Survived")
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 0              1         0       3            Braund, Mr. Owen Harris    male
# 519          520         0       3                Pavlovic, Mr. Stefo    male
# 521          522         0       3                    Vovk, Mr. Janko    male
# 522          523         0       3                 Lahoud, Mr. Sarkis    male
# 524          525         0       3                  Kassem, Mr. Fared    male
# ..           ...       ...     ...                                ...     ...
# 546          547         1       2  Beane, Mrs. Edward (Ethel Clarke)  female
# 215          216         1       1            Newell, Miss. Madeleine  female
# 216          217         1       3             Honkanen, Miss. Eliina  female
# 218          219         1       1              Bazzani, Miss. Albina  female
# 445          446         1       1          Dodge, Master. Washington    male
#
# ...

# %%
df.sort_values(by='Name')
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 845          846         0       3                    Abbing, Mr. Anthony
# 746          747         0       3            Abbott, Mr. Rossmore Edward
# 279          280         1       3       Abbott, Mrs. Stanton (Rosa Hunt)
# 308          309         0       2                    Abelson, Mr. Samuel
# 874          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
# ..           ...       ...     ...                                    ...
# 286          287         1       3                de Mulder, Mr. Theodore
# 282          283         0       3              de Pelsmaeker, Mr. Alfons
# 361          362         0       2              del Carlo, Mr. Sebastiano
# 153          154         0       3        van Billiard, Mr. Austin Blyler
# 868          869         0       3            van Melkebeke, Mr. Philemon
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# 89. Find passengers whose names contain "Mrs".
# 90. Find passengers whose names contain "Miss".
# 91. Find passengers whose names contain "Mr".
# 92. Find passengers whose names contain "Master".
# 93. Find passengers whose names contain "Rose".
# 94. Find passengers whose names contain the letter "a".

# %%
df['Name'].str.contains("Mrs")
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Name, Length: 891, dtype: bool

# %%
df['Name'].str.contains("Miss")
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Name, Length: 891, dtype: bool

# %%
df['Name'].str.contains("Mr")
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 886    False
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Name, Length: 891, dtype: bool

# %%
df['Name'].str.contains("Master")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Name, Length: 891, dtype: bool

# %%
df['Name'].str.contains("Rose")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Name, Length: 891, dtype: bool

# %%
df['Name'].str.contains("a")
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 886    True
# 887    True
# 888    True
# 889    True
# 890    True
# Name: Name, Length: 891, dtype: bool

# %% [markdown]
# Find passengers travelling in either first or third class.
# 96. Find passengers whose Embarked value is either S or C.
# 97. Find passengers whose Sex is either male or female.
# 98. Find passengers whose Pclass is either 1 or 2.

# %%
df[df["Embarked"].isin(["S","C"])]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Pclass'].isin([1,3])]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Sex'].isin(['male','female'])]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Pclass'].isin([1,2])]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 9             10         1       2
# 11            12         1       1
# ..           ...       ...     ...
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 99. Change the Name of row 0 to "arsalan" using loc.
# 100. Change the Fare of row 0 to 100 using loc.
# 101. Replace "male" with "M" in the Sex column.
# 102. Replace "female" with "F" in the Sex column.
# 103. Replace 0 with "Dead" in Survived.
# 104. Replace 1 with "Alive" in Survived.
# 105. Practice changing a specific passenger's Age using loc.

# %%
df.loc[0,"Name"]='arsalan'

# %%
df.loc[0,'Fare']=100

# %%
df.replace("female","F",inplace=True)

# %%
df.replace("male","M",inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris   M  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   F  38.0      1
# 2                               Heikkinen, Miss. Laina   F  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   F  35.0      1
# 4                             Allen, Mr. William Henry   M  35.0      0
# ..                                                 ...  ..   ...    ...
# ...

# %%
df.replace(0,"Dead",inplace=True)

# %%
df.replace(1,"Alive",inplace=True)

# %%
df.loc[0,"Age"]=33

# %%
df
# Out:
#     PassengerId Survived Pclass  \
# 0         Alive     Dead      3
# 1             2    Alive  Alive
# 2             3    Alive      3
# 3             4    Alive  Alive
# 4             5     Dead      3
# ..          ...      ...    ...
# 886         887     Dead      2
# 887         888    Alive  Alive
# 888         889     Dead      3
# 889         890    Alive  Alive
# 890         891     Dead      3
#
#                                                   Name Sex   Age  SibSp Parch  \
# 0                              Braund, Mr. Owen Harris   M    33  Alive  Dead
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   F  38.0  Alive  Dead
# 2                               Heikkinen, Miss. Laina   F  26.0   Dead  Dead
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   F  35.0  Alive  Dead
# 4                             Allen, Mr. William Henry   M  35.0   Dead  Dead
# ..                                                 ...  ..   ...    ...   ...
# ...

# %% [markdown]
# 106. Find the average age of female passengers.
# 107. Find the average age of male passengers.
# 108. Find the average fare paid by first-class passengers.
# 109. Find the average fare paid by third-class passengers.
# 110. Find the number of female passengers who survived.
# 111. Find the number of male passengers who survived.
# 112. Find the number of female passengers who did not survive.
# 113. Find the number of male passengers who did not survive.
# 114. Find passengers older than 50 who survived, and display only their Name, Age, and Fare.
# 115. Find female passengers younger than 18 who survived.
# 116. Find passengers in first class who paid more than 100.
# 117. Find passengers in third class who paid less than 10.
# 118. Find the oldest passenger who survived.
# 119. Find the passenger who paid the highest fare.
# 120. Find the passenger with the lowest fare.

# %%
df[df["Sex"]=="female"]["Age"].mean()
# Out:
# np.float64(27.915708812260537)

# %%
df[df["Sex"]=="male"]["Age"].mean()
# Out:
# np.float64(30.72664459161148)

# %%
df[df["Pclass"]==1]["Fare"].mean()
# Out:
# np.float64(84.1546875)

# %%
df[df["Pclass"]==3]["Fare"].mean()
# Out:
# np.float64(13.675550101832993)

# %%
((df["Survived"]==1)&
    (df["Sex"]=="female")).sum()
# Out:
# np.int64(233)

# %%
((df["Survived"]==1)&
    (df["Sex"]=="male")).sum()
# Out:
# np.int64(109)

# %%
((df["Survived"]==0)&
    (df["Sex"]=="female")).sum()
# Out:
# np.int64(81)

# %%
((df["Survived"]==0)&
    (df["Sex"]=="male")).sum()
# Out:
# np.int64(468)

# %%
df[(df["Age"]>50)&
   (df["Survived"]==1)][["Name","Age","Fare"]]
# Out:
#                                                   Name   Age      Fare
# 11                            Bonnell, Miss. Elizabeth  58.0   26.5500
# 15                    Hewlett, Mrs. (Mary D Kingcome)   55.0   16.0000
# 195                               Lurette, Miss. Elise  58.0  146.5208
# 268      Graham, Mrs. William Thompson (Edith Junkins)  58.0  153.4625
# 275                  Andrews, Miss. Kornelia Theodosia  63.0   77.9583
# 366   Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  60.0   75.2500
# 449                     Peuchen, Major. Arthur Godfrey  52.0   30.5000
# 483                             Turkula, Mrs. (Hedwig)  63.0    9.5875
# 496                     Eustis, Miss. Elizabeth Mussey  54.0   78.2667
# 513     Rothschild, Mrs. Martin (Elizabeth L. Barrett)  54.0   59.4000
# 570                                 Harris, Mr. George  62.0   10.5000
# 571      Appleton, Mrs. Edward Dale (Charlotte Lamson)  53.0   51.4792
# ...

# %%
df[(df["Survived"]==1)&
    (df["Sex"]=="female")&
    (df["Age"]<18)]
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 10            11         1       3
# 22            23         1       3
# 39            40         1       3
# 43            44         1       2
# 58            59         1       2
# 68            69         1       3
# 84            85         1       2
# 156          157         1       3
# 172          173         1       3
# 184          185         1       3
# 208          209         1       3
# 233          234         1       3
# 237          238         1       2
# 307          308         1       1
# 329          330         1       1
# 381          382         1       3
# 389          390         1       2
# 435          436         1       1
# 446          447         1       2
# 448          449         1       3
# 469          470         1       3
# 479          480         1       3
# 504          505         1       1
# 530          531         1       2
# ...

# %%
df[(df["Pclass"]==1)&
    (df["Fare"]>100)
]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
# 215          216         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 297          298         0       1
# 299          300         1       1
# 305          306         1       1
# 306          307         1       1
# 307          308         1       1
# 311          312         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 332          333         0       1
# 334          335         1       1
# 337          338         1       1
# 341          342         1       1
# 373          374         0       1
# 377          378         0       1
# 380          381         1       1
# ...

# %%
df[(df["Pclass"]==3)&
    (df["Fare"]<10)
]
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris    male
# 2              3         1       3          Heikkinen, Miss. Laina  female
# 4              5         0       3        Allen, Mr. William Henry    male
# 5              6         0       3                Moran, Mr. James    male
# 12            13         0       3  Saundercock, Mr. William Henry    male
# ..           ...       ...     ...                             ...     ...
# 877          878         0       3            Petroff, Mr. Nedelio    male
# 878          879         0       3              Laleff, Mr. Kristo    male
# 881          882         0       3              Markun, Mr. Johann    male
# 884          885         0       3          Sutehall, Mr. Henry Jr    male
# 890          891         0       3             Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket    Fare Cabin Embarked
# ...

# %%
df[df["Survived"]==1].sort_values(by="Age",ascending=False).head(1)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
df.sort_values(by="Fare",ascending=False).head(1)
# Out:
#      PassengerId  Survived  Pclass              Name     Sex   Age  SibSp  \
# 258          259         1       1  Ward, Miss. Anna  female  35.0      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 258      0  PC 17755  512.3292   NaN        C

# %%
df.sort_values(by="Fare",ascending=True).head(1)
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 271          272         1       3  Tornquist, Mr. William Henry  male  25.0
#
#      SibSp  Parch Ticket  Fare Cabin Embarked
# 271      0      0   LINE   0.0   NaN        S

# %% [markdown]
# 136. How many passengers survived?
# 137. What percentage of passengers survived?
# 138. How many passengers were male and female?
# 139. What was the average age of survivors?
# 140. What was the average age of people who didn't survive?
# 141. What was the average fare of survivors?
# 142. Which passenger class had how many passengers?
# 143. Find female survivors who paid more than 50.
# 144. Find male survivors who were younger than 25.
# 145. Find the 10 highest-paying passengers who survived.
# 146. Find the 10 youngest passengers who survived.
# 147. Find passengers whose names contain "Mrs" and whose age is greater than 30.
# 148. Find passengers from C who were in first class and survived.
# 149. Find passengers from S who were in third class and did not survive.

# %%
(df["Survived"]==1).sum()
# Out:
# np.int64(342)

# %%
((df["Survived"]==1).sum()/df.shape[0])*100
# Out:
# np.float64(38.38383838383838)

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df[df["Survived"]==1]["Age"].mean()
# Out:
# np.float64(28.343689655172415)

# %%
df[df["Survived"]==0]["Age"].mean()
# Out:
# np.float64(30.62617924528302)

# %%
df[df["Survived"]==1]["Fare"].mean()
# Out:
# np.float64(48.39540760233918)

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df[(df["Sex"]=="female")&
    (df["Survived"]==1)&
    (df["Fare"]>50)
]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 31            32         1       1
# 52            53         1       1
# 61            62         1       1
# ..           ...       ...     ...
# 835          836         1       1
# 849          850         1       1
# 856          857         1       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 61                                 Icard, Miss. Amelie  female  38.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df["Sex"]=="male")&
    (df["Survived"]==1)&
    (df["Age"]<25)
]
# Out:
#      PassengerId  Survived  Pclass  \
# 78            79         1       2
# 97            98         1       1
# 125          126         1       3
# 127          128         1       3
# 165          166         1       3
# 183          184         1       2
# 193          194         1       2
# 204          205         1       3
# 220          221         1       3
# 226          227         1       2
# 261          262         1       3
# 283          284         1       3
# 305          306         1       1
# 340          341         1       2
# 348          349         1       3
# 391          392         1       3
# 407          408         1       2
# 445          446         1       1
# 489          490         1       3
# 549          550         1       2
# 550          551         1       1
# 553          554         1       3
# 622          623         1       3
# 664          665         1       3
# 751          752         1       3
# ...

# %%
df[df["Survived"]==1].sort_values(by="Fare",ascending = False).head(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 258          259         1       1
# 679          680         1       1
# 737          738         1       1
# 341          342         1       1
# 88            89         1       1
# 311          312         1       1
# 742          743         1       1
# 299          300         1       1
# 700          701         1       1
# 716          717         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 258                                   Ward, Miss. Anna  female  35.0      0
# 679                 Cardeza, Mr. Thomas Drake Martinez    male  36.0      0
# 737                             Lesurer, Mr. Gustave J    male  35.0      0
# 341                     Fortune, Miss. Alice Elizabeth  female  24.0      3
# 88                          Fortune, Miss. Mabel Helen  female  23.0      3
# 311                         Ryerson, Miss. Emily Borie  female  18.0      2
# ...

# %%
df[df["Survived"]==1].sort_values(by="Age",ascending = True).head(10)
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 831          832         1       2  Richards, Master. George Sibley    male
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 381          382         1       3      Nakid, Miss. Maria ("Mary")  female
# 827          828         1       2            Mallet, Master. Andre    male
# 788          789         1       3       Dean, Master. Bertram Vere    male
#
#       Age  SibSp  Parch           Ticket      Fare    Cabin Embarked
# ...

# %%
df[(df["Name"].str.contains("Mrs"))&
    (df["Age"]>30)
]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 15            16         1       2
# 18            19         0       3
# 25            26         1       3
# ..           ...       ...     ...
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df["Embarked"]=="C")&
    (df["Pclass"]==1)&
    (df["Survived"]==1)
    ]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 31            32         1       1
# 52            53         1       1
# 97            98         1       1
# 194          195         1       1
# 195          196         1       1
# 209          210         1       1
# 215          216         1       1
# 218          219         1       1
# 256          257         1       1
# 258          259         1       1
# 291          292         1       1
# 299          300         1       1
# 306          307         1       1
# 307          308         1       1
# 309          310         1       1
# 310          311         1       1
# 311          312         1       1
# 319          320         1       1
# 325          326         1       1
# 329          330         1       1
# 337          338         1       1
# 366          367         1       1
# 369          370         1       1
# 370          371         1       1
# ...

# %%
df[(df["Embarked"]=="S")&
    (df["Pclass"]==3)&
    (df["Survived"]==0)
    ]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 12            13         0       3            Saundercock, Mr. William Henry
# 13            14         0       3               Andersson, Mr. Anders Johan
# ..           ...       ...     ...                                       ...
# 878          879         0       3                        Laleff, Mr. Kristo
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df[df["Survived"]==1][["Name","Sex","Age","Pclass","Survived","Fare"]]
# Out:
#                                                   Name     Sex   Age  Pclass  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1
# 2                               Heikkinen, Miss. Laina  female  26.0       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0       1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0       3
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0       2
# ..                                                 ...     ...   ...     ...
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0       3
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0       1
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0       2
# 887                       Graham, Miss. Margaret Edith  female  19.0       1
# 889                              Behr, Mr. Karl Howell    male  26.0       1
#
#      Survived     Fare
# ...
